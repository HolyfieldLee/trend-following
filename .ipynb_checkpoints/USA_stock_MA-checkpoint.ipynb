# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = 'QQQ'
# 오늘 날짜로부터 5년 전 데이터 다운로드
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

data = yf.download(ticker, start=start_date, end=end_date)

if data.empty:
    print(f"{ticker}에 대한 데이터를 가져오는 데 실패했습니다. 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"{ticker} 데이터 (최근 5년):\n", data.tail())

    # 2. 이동평균 계산
    # 단기 이동평균 (예: 50일)
    short_window = 50
    # 장기 이동평균 (예: 200일)
    long_window = 200

    data['Short_MA'] = data['Close'].rolling(window=short_window, min_periods=1).mean()
    data['Long_MA'] = data['Close'].rolling(window=long_window, min_periods=1).mean()

    # 3. 거래 신호 생성
    # 'Signal' 컬럼: 1은 매수, -1은 매도, 0은 유지
    data['Signal'] = 0
    # 단기 MA가 장기 MA를 상향 돌파하면 매수 신호 (1)
    data.loc[data.index[short_window:], 'Signal'] = np.where(data['Short_MA'][short_window:] > data['Long_MA'][short_window:], 1, 0)
    # 단기 MA가 장기 MA를 하향 돌파하면 매도 신호 (-1)
    # 'Signal' 컬럼의 변화를 감지하여 실제 거래 시점을 포착 (Positions)
    data['Position'] = data['Signal'].diff()

    print("\n이동평균 및 거래 신호 데이터:\n", data[['Close', 'Short_MA', 'Long_MA', 'Signal', 'Position']].tail(10))

    # 4. 시각화
    plt.figure(figsize=(14, 7))

    # 주가 그래프
    plt.plot(data['Close'], label='Close Price', alpha=0.5)
    # 단기 이동평균선
    plt.plot(data['Short_MA'], label=f'{short_window}-Day MA', alpha=0.75)
    # 장기 이동평균선
    plt.plot(data['Long_MA'], label=f'{long_window}-Day MA', alpha=0.75)

    # 매수 신호 지점 (Position == 1)
    plt.plot(data[data['Position'] == 1].index,
             data['Short_MA'][data['Position'] == 1],
             '^', markersize=10, color='g', lw=0, label='Buy Signal')

    # 매도 신호 지점 (Position == -1)
    plt.plot(data[data['Position'] == -1].index,
             data['Short_MA'][data['Position'] == -1],
             'v', markersize=10, color='r', lw=0, label='Sell Signal')

    plt.title(f'{ticker} stock stragy for 5 years')
    plt.xlabel('date')
    plt.ylabel('stock price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# QQQ 데이터 (최근 5년):
#  Price            Close        High         Low        Open    Volume
# Ticker             QQQ         QQQ         QQQ         QQQ       QQQ
# Date
# 2025-05-16  521.510010  521.700012  517.099976  520.659973  48394600
# 2025-05-19  522.010010  522.530029  514.239990  514.239990  52536200
# 2025-05-20  520.270020  520.929993  516.659973  519.469971  42517600
# 2025-05-21  513.039978  523.000000  511.239990  516.270020  71292800
# 2025-05-22  514.000000  517.710022  512.299988  513.659973  55331200
#
# 이동평균 및 거래 신호 데이터:
#  Price            Close    Short_MA     Long_MA Signal Position
# Ticker             QQQ
# Date
# 2025-05-09  487.970001  471.037989  490.005172      0      0.0
# 2025-05-12  507.850006  471.046722  490.237937      0      0.0
# 2025-05-13  515.590027  471.432326  490.534838      0      0.0
# 2025-05-14  518.679993  471.909684  490.823795      0      0.0
# 2025-05-15  519.250000  472.269434  491.110972      0      0.0
# 2025-05-16  521.510010  472.950173  491.441156      0      0.0
# 2025-05-19  522.010010  473.569219  491.706445      0      0.0
# 2025-05-20  520.270020  474.534098  492.019827      0      0.0
# 2025-05-21  513.039978  475.376942  492.351364      0      0.0
# 2025-05-22  514.000000  476.132745  492.754300      0      0.0

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\glasr\anaconda3\lib\site-packages (0.2.59)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas>=1.3.0 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (0.10.0)
# Requirement already satisfied: protobuf<6,>=5.29.0 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (5.29.4)
# Requirement already satisfied: websockets>=11.0 in c:\users\glasr\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\glasr\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\glasr\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\glasr\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\glasr\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\glasr\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\glasr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\glasr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\glasr\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\glasr\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\glasr\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %% [markdown]
# # 한국주식 이평선 분석

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = '260970.KQ'  # 한국주식 티커 (KS: 코스피, KQ: 코스닥)
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"{ticker}에 대한 데이터를 가져오는 데 실패했습니다. 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"{ticker} 데이터 (최근 5년):\n", data.tail())

    # 2. 이동평균 계산 (기존 50일, 200일 + 새로 추가)
    windows = [5, 20, 50, 120, 200]  # 5일, 20일, 50일, 120일, 200일
    ma_labels = ['5-Day', '20-Day', '50-Day', '120-Day', '200-Day']
    colors = ['cyan', 'magenta', 'blue', 'orange', 'red']  # 각 이평선 색상
    
    for window, label in zip(windows, ma_labels):
        data[f'{window}_MA'] = data['Close'].rolling(window=window, min_periods=1).mean()

    # 3. 거래 신호 생성 (기존 전략 유지 - 50일 vs 200일 기준)
    data['Signal'] = 0
    data.loc[data.index[50:], 'Signal'] = np.where(data['50_MA'][50:] > data['200_MA'][50:], 1, 0)
    data['Position'] = data['Signal'].diff()

    print("\n이동평균 및 거래 신호 데이터:\n", data[['Close', '5_MA', '20_MA', '50_MA', '120_MA', '200_MA', 'Signal', 'Position']].tail(10))

    # 4. 시각화 (추가된 이평선 반영)
    plt.figure(figsize=(16, 8))
    plt.plot(data['Close'], label='Close Price', alpha=0.3, linewidth=2)

    # 모든 이동평균선 플롯
    for window, color, label in zip(windows, colors, ma_labels):
        plt.plot(data[f'{window}_MA'], label=f'{label} MA', color=color, alpha=0.75)

    # 매수/매도 신호 표시 (기존 전략 기준)
    plt.plot(data[data['Position'] == 1].index,
             data['50_MA'][data['Position'] == 1],
             '^', markersize=12, color='g', lw=0, label='Buy Signal (50>200)')
    plt.plot(data[data['Position'] == -1].index,
             data['50_MA'][data['Position'] == -1],
             'v', markersize=12, color='r', lw=0, label='Sell Signal (50<200)')

    plt.title(f'{ticker} Moving Average Strategy (5/20/50/120/200 Days)', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (KRW)', fontsize=12)
    plt.legend(loc='upper left', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# 260970.KQ 데이터 (최근 5년):
#  Price          Close      High       Low      Open    Volume
# Ticker     260970.KQ 260970.KQ 260970.KQ 260970.KQ 260970.KQ
# Date
# 2025-05-19   88600.0   92000.0   87100.0   90000.0     96505
# 2025-05-20   92400.0   93400.0   89500.0   90100.0     89609
# 2025-05-21   91400.0   92600.0   89800.0   92400.0     43586
# 2025-05-22   88900.0   91600.0   87700.0   90900.0     67791
# 2025-05-23   87800.0   90200.0   85900.0   88900.0     88694
#
# 이동평균 및 거래 신호 데이터:
#  Price          Close     5_MA    20_MA    50_MA        120_MA        200_MA  \
# Ticker     260970.KQ
# Date
# 2025-05-12   96600.0  95340.0  85730.0  75040.0  56437.706510  47987.314268
# 2025-05-13   99500.0  96900.0  87355.0  75884.0  57007.118994  48277.753076
# 2025-05-14   97400.0  98480.0  88745.0  76572.0  57563.979183  48561.402666
# 2025-05-15  100200.0  98820.0  90255.0  77346.0  58147.058854  48867.958115
# 2025-05-16   90000.0  96740.0  90580.0  77848.0  58653.384701  49118.318467
# 2025-05-19   88600.0  95140.0  90880.0  78248.0  59136.911556  49367.863447
# 2025-05-20   92400.0  93720.0  91420.0  78654.0  59653.341992  49632.202881
# 2025-05-21   91400.0  92520.0  91690.0  79076.0  60162.676025  49893.768779
# 2025-05-22   88900.0  90260.0  91855.0  79450.0  60651.176725  50133.434053
# 2025-05-23   87800.0  89820.0  91920.0  79808.0  61135.458464  50375.268252
#
# Price      Signal Position
# Ticker
# Date
# 2025-05-12      1      0.0
# 2025-05-13      1      0.0
# 2025-05-14      1      0.0
# 2025-05-15      1      0.0
# 2025-05-16      1      0.0
# 2025-05-19      1      0.0
# 2025-05-20      1      0.0
# 2025-05-21      1      0.0
# 2025-05-22      1      0.0
# 2025-05-23      1      0.0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = '260970.KQ'  # 한국주식 티커 (KS: 코스피, KQ: 코스닥)
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"{ticker}에 대한 데이터를 가져오는 데 실패했습니다. 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"{ticker} 데이터 (최근 5년):\n", data.tail())

    # 2. 이동평균 계산 (기존 50일, 200일 + 새로 추가)
    windows = [5, 20, 50, 120, 200]  # 5일, 20일, 50일, 120일, 200일
    ma_labels = ['5-Day', '20-Day', '50-Day', '120-Day', '200-Day']
    colors = ['cyan', 'magenta', 'blue', 'orange', 'red']  # 각 이평선 색상
    
    for window, label in zip(windows, ma_labels):
        data[f'{window}_MA'] = data['Close'].rolling(window=window, min_periods=1).mean()

    # 3. 거래 신호 생성 (기존 전략 유지 - 50일 vs 200일 기준)
    data['Signal'] = 0
    # 200일 MA를 사용하므로 최소 200일 데이터 필요
    min_signal_idx = max(50, 200) 
    if len(data) > min_signal_idx:
        data.loc[data.index[min_signal_idx:], 'Signal'] = np.where(data['50_MA'][min_signal_idx:] > data['200_MA'][min_signal_idx:], 1, 0)
    else:
        print("Warning: Not enough data points to generate full 50-day and 200-day MA signals.")
        data['Signal'] = 0 
        
    data['Position'] = data['Signal'].diff()

    # 4. 정배열 'nice' 신호 생성 및 진입 신호 (추가된 부분)
    min_bullish_idx = max(windows) # 모든 MA가 계산될 수 있는 충분한 데이터가 필요합니다.
    
    if len(data) > min_bullish_idx:
        # 4-1. 모든 MA가 정배열인 상태를 나타내는 임시 컬럼 생성 (5 > 20 > 50 > 120 > 200)
        data['Is_Bullish_Aligned'] = np.where(
            (data['5_MA'] > data['20_MA']) &
            (data['20_MA'] > data['50_MA']) &
            (data['50_MA'] > data['120_MA']) &
            (data['120_MA'] > data['200_MA']),
            1, 0
        )
        
        # 4-2. 역정배열에서 정배열로 '전환'되는 시점만 포착하여 'Nice_Entry_Signal' 생성
        data['Nice_Entry_Signal'] = np.where(
            (data['Is_Bullish_Aligned'].shift(1) == 0) & (data['Is_Bullish_Aligned'] == 1),
            1, 0
        )
        # NaN 값(초기 부분)은 0으로 채움
        data['Nice_Entry_Signal'] = data['Nice_Entry_Signal'].fillna(0)
    else:
        data['Is_Bullish_Aligned'] = 0
        data['Nice_Entry_Signal'] = 0 # 데이터가 부족하면 신호 없음


    print("\n이동평균 및 거래 신호 데이터:\n", data[['Close', '5_MA', '20_MA', '50_MA', '120_MA', '200_MA', 'Signal', 'Position', 'Is_Bullish_Aligned', 'Nice_Entry_Signal']].tail(10))

    # 5. 시각화 (추가된 이평선 반영)
    plt.figure(figsize=(16, 8))
    plt.plot(data['Close'], label='Close Price', alpha=0.3, linewidth=2)

    # 모든 이동평균선 플롯
    for window, color, label in zip(windows, colors, ma_labels): # <-- 이 부분에 'colors' 추가
        plt.plot(data[f'{window}_MA'], label=f'{label} MA', color=color, alpha=0.75)

    # 매수/매도 신호 표시 (기존 전략 기준)
    plt.plot(data[data['Position'] == 1].index,
             data['50_MA'][data['Position'] == 1],
             '^', markersize=12, color='g', lw=0, label='Buy Signal (50>200)')
    plt.plot(data[data['Position'] == -1].index,
             data['50_MA'][data['Position'] == -1],
             'v', markersize=12, color='r', lw=0, label='Sell Signal (50<200)')

    # 정배열 'nice' 진입 신호 표시 추가
    plt.plot(data[data['Nice_Entry_Signal'] == 1].index,
             data['Close'][data['Nice_Entry_Signal'] == 1], # 종가 위치에 마커 표시
             '*', markersize=10, color='mediumspringgreen', alpha=0.9, lw=0, label='nice (Bullish Entry)')


    plt.title(f'{ticker} Moving Average Strategy (5/20/50/120/200 Days)', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (KRW)', fontsize=12) # 한국 주식 기준 화폐 단위
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10) # 범례를 그래프 밖에 배치
    plt.subplots_adjust(right=0.8) # 그래프 오른쪽 여백을 늘려 범례가 들어갈 공간 확보
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# 260970.KQ 데이터 (최근 5년):
#  Price          Close      High       Low      Open    Volume
# Ticker     260970.KQ 260970.KQ 260970.KQ 260970.KQ 260970.KQ
# Date
# 2025-05-19   88600.0   92000.0   87100.0   90000.0     96505
# 2025-05-20   92400.0   93400.0   89500.0   90100.0     89609
# 2025-05-21   91400.0   92600.0   89800.0   92400.0     43586
# 2025-05-22   88900.0   91600.0   87700.0   90900.0     67791
# 2025-05-23   87700.0   90200.0   85900.0   88900.0     90881
#
# 이동평균 및 거래 신호 데이터:
#  Price          Close     5_MA    20_MA    50_MA        120_MA        200_MA  \
# Ticker     260970.KQ
# Date
# 2025-05-12   96600.0  95340.0  85730.0  75040.0  56437.706510  47987.314268
# 2025-05-13   99500.0  96900.0  87355.0  75884.0  57007.118994  48277.753076
# 2025-05-14   97400.0  98480.0  88745.0  76572.0  57563.979183  48561.402666
# 2025-05-15  100200.0  98820.0  90255.0  77346.0  58147.058854  48867.958115
# 2025-05-16   90000.0  96740.0  90580.0  77848.0  58653.384701  49118.318467
# 2025-05-19   88600.0  95140.0  90880.0  78248.0  59136.911556  49367.863447
# 2025-05-20   92400.0  93720.0  91420.0  78654.0  59653.341992  49632.202881
# 2025-05-21   91400.0  92520.0  91690.0  79076.0  60162.676025  49893.768779
# 2025-05-22   88900.0  90260.0  91855.0  79450.0  60651.176725  50133.434053
# 2025-05-23   87700.0  89800.0  91915.0  79806.0  61134.625130  50374.768252
#
# Price      Signal Position Is_Bullish_Aligned Nice_Entry_Signal
# Ticker
# Date
# 2025-05-12      1      0.0                  1                 0
# 2025-05-13      1      0.0                  1                 0
# 2025-05-14      1      0.0                  1                 0
# 2025-05-15      1      0.0                  1                 0
# 2025-05-16      1      0.0                  1                 0
# 2025-05-19      1      0.0                  1                 0
# 2025-05-20      1      0.0                  1                 0
# 2025-05-21      1      0.0                  1                 0
# 2025-05-22      1      0.0                  0                 0
# 2025-05-23      1      0.0                  0                 0

# %% [markdown]
# # 미국주식 이평선 분석

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = 'AAPL'  # 미국 주식 티커 (예: Apple Inc.)
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"{ticker}에 대한 데이터를 가져오는 데 실패했습니다. 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"{ticker} 데이터 (최근 5년):\n", data.tail())

    # 2. 이동평균 계산 (기존 50일, 200일 + 새로 추가)
    windows = [5, 20, 50, 120, 200]  # 5일, 20일, 50일, 120일, 200일
    ma_labels = ['5-Day', '20-Day', '50-Day', '120-Day', '200-Day']
    colors = ['cyan', 'magenta', 'blue', 'orange', 'red']  # 각 이평선 색상
    
    for window, label in zip(windows, ma_labels):
        data[f'{window}_MA'] = data['Close'].rolling(window=window, min_periods=1).mean()

    # 3. 거래 신호 생성 (기존 전략 유지 - 50일 vs 200일 기준)
    data['Signal'] = 0
    data.loc[data.index[50:], 'Signal'] = np.where(data['50_MA'][50:] > data['200_MA'][50:], 1, 0)
    data['Position'] = data['Signal'].diff()

    print("\n이동평균 및 거래 신호 데이터:\n", data[['Close', '5_MA', '20_MA', '50_MA', '120_MA', '200_MA', 'Signal', 'Position']].tail(10))

    # 4. 시각화 (추가된 이평선 반영)
    plt.figure(figsize=(16, 8))
    plt.plot(data['Close'], label='Close Price', alpha=0.3, linewidth=2)

    # 모든 이동평균선 플롯
    for window, color, label in zip(windows, colors, ma_labels):
        plt.plot(data[f'{window}_MA'], label=f'{label} MA', color=color, alpha=0.75)

    # 매수/매도 신호 표시 (기존 전략 기준)
    plt.plot(data[data['Position'] == 1].index,
             data['50_MA'][data['Position'] == 1],
             '^', markersize=12, color='g', lw=0, label='Buy Signal (50>200)')
    plt.plot(data[data['Position'] == -1].index,
             data['50_MA'][data['Position'] == -1],
             'v', markersize=12, color='r', lw=0, label='Sell Signal (50<200)')

    plt.title(f'{ticker} Moving Average Strategy (5/20/50/120/200 Days)', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (USD)', fontsize=12) # Label changed to USD
    plt.legend(loc='upper left', fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# AAPL 데이터 (최근 5년):
#  Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-05-16  211.259995  212.570007  209.770004  212.360001  54737900
# 2025-05-19  208.779999  209.479996  204.259995  207.910004  46140500
# 2025-05-20  206.860001  208.470001  205.029999  207.669998  42496600
# 2025-05-21  202.089996  207.039993  200.710007  205.169998  59211800
# 2025-05-22  201.360001  202.750000  199.699997  200.710007  46633900
#
# 이동평균 및 거래 신호 데이터:
#  Price            Close        5_MA       20_MA       50_MA      120_MA  \
# Ticker            AAPL
# Date
# 2025-05-09  198.270004  197.674780  202.304710  210.759622  227.130344
# 2025-05-12  210.789993  200.106873  202.949685  210.144956  226.989670
# 2025-05-13  212.929993  203.042868  203.483446  209.649191  226.893599
# 2025-05-14  212.330002  206.310272  204.006182  209.183371  226.767422
# 2025-05-15  211.449997  209.153998  204.877903  208.703745  226.631750
# 2025-05-16  211.259995  211.751996  205.604801  208.228509  226.488509
# 2025-05-19  208.779999  211.349997  206.398450  207.628971  226.328591
# 2025-05-20  206.860001  210.135999  206.767529  207.222529  226.141451
# 2025-05-21  202.089996  208.087997  206.655425  206.853313  225.889621
# 2025-05-22  201.360001  206.069998  206.318570  206.546597  225.613502
#
# Price           200_MA Signal Position
# Ticker
# Date
# 2025-05-09  225.825711      0      0.0
# 2025-05-12  225.792048      0      0.0
# 2025-05-13  225.774310      0      0.0
# 2025-05-14  225.751233      0      0.0
# 2025-05-15  225.722362      0      0.0
# 2025-05-16  225.689754      0      0.0
# 2025-05-19  225.628423      0      0.0
# 2025-05-20  225.576005      0      0.0
# 2025-05-21  225.492273      0      0.0
# 2025-05-22  225.457593      0      0.0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = 'GE'  # 미국 주식 티커 (예: Apple Inc.)
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"{ticker}에 대한 데이터를 가져오는 데 실패했습니다. 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"{ticker} 데이터 (최근 5년):\n", data.tail())

    # 2. 이동평균 계산 (기존 50일, 200일 + 새로 추가)
    windows = [5, 20, 50, 120, 200]  # 5일, 20일, 50일, 120일, 200일
    ma_labels = ['5-Day', '20-Day', '50-Day', '120-Day', '200-Day']
    colors = ['cyan', 'magenta', 'blue', 'orange', 'red']  # 각 이평선 색상
    
    for window, label in zip(windows, ma_labels):
        data[f'{window}_MA'] = data['Close'].rolling(window=window, min_periods=1).mean()

    # 3. 거래 신호 생성 (기존 전략 유지 - 50일 vs 200일 기준)
    data['Signal'] = 0
    min_signal_idx = max(50, 200) 
    if len(data) > min_signal_idx:
        data.loc[data.index[min_signal_idx:], 'Signal'] = np.where(data['50_MA'][min_signal_idx:] > data['200_MA'][min_signal_idx:], 1, 0)
    else:
        print("Warning: Not enough data points to generate full 50-day and 200-day MA signals.")
        data['Signal'] = 0 
        
    data['Position'] = data['Signal'].diff()

    # 4. 정배열 'nice' 신호 생성 및 진입 신호 (가장 중요한 변경 사항!)
    min_bullish_idx = max(windows)
    
    if len(data) > min_bullish_idx:
        # 4-1. 모든 MA가 정배열인 상태를 나타내는 임시 컬럼 생성
        data['Is_Bullish_Aligned'] = np.where(
            (data['5_MA'] > data['20_MA']) &
            (data['20_MA'] > data['50_MA']) &
            (data['50_MA'] > data['120_MA']) &
            (data['120_MA'] > data['200_MA']),
            1, 0
        )
        
        # 4-2. 역정배열(0)에서 정배열(1)로 '전환'되는 시점만 포착
        # Is_Bullish_Aligned가 0에서 1로 바뀔 때만 1을 표시
        data['Nice_Entry_Signal'] = np.where(
            (data['Is_Bullish_Aligned'].shift(1) == 0) & (data['Is_Bullish_Aligned'] == 1),
            1, 0
        )
        # NaN 값(초기 부분)은 0으로 채움
        data['Nice_Entry_Signal'] = data['Nice_Entry_Signal'].fillna(0)
    else:
        data['Is_Bullish_Aligned'] = 0
        data['Nice_Entry_Signal'] = 0 # 데이터가 부족하면 신호 없음


    print("\n이동평균 및 거래 신호 데이터:\n", data[['Close', '5_MA', '20_MA', '50_MA', '120_MA', '200_MA', 'Signal', 'Position', 'Is_Bullish_Aligned', 'Nice_Entry_Signal']].tail(10))

    # 5. 시각화 (추가된 이평선 반영)
    plt.figure(figsize=(16, 8))
    plt.plot(data['Close'], label='Close Price', alpha=0.3, linewidth=2)

    # 모든 이동평균선 플롯
    for window, color, label in zip(windows, colors, ma_labels):
        plt.plot(data[f'{window}_MA'], label=f'{label} MA', color=color, alpha=0.75)

    # 매수/매도 신호 표시 (기존 전략 기준)
    plt.plot(data[data['Position'] == 1].index,
             data['50_MA'][data['Position'] == 1],
             '^', markersize=12, color='g', lw=0, label='Buy Signal (50>200)')
    plt.plot(data[data['Position'] == -1].index,
             data['50_MA'][data['Position'] == -1],
             'v', markersize=12, color='r', lw=0, label='Sell Signal (50<200)')

    # 정배열 'nice' 진입 신호 표시 추가 (수정된 부분)
    plt.plot(data[data['Nice_Entry_Signal'] == 1].index,
             data['Close'][data['Nice_Entry_Signal'] == 1], # 종가 위치에 마커 표시
             '*', markersize=10, color='mediumspringgreen', alpha=0.9, lw=0, label='nice (Bullish Entry)')


    plt.title(f'{ticker} Moving Average Strategy (5/20/50/120/200 Days)', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (USD)', fontsize=12) 
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10) 
    plt.subplots_adjust(right=0.8) 
    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# GE 데이터 (최근 5년):
#  Price            Close        High         Low        Open   Volume
# Ticker              GE          GE          GE          GE       GE
# Date
# 2025-05-16  231.779999  232.320007  227.589996  229.070007  4651700
# 2025-05-19  235.289993  235.869995  228.919998  229.500000  4734400
# 2025-05-20  235.259995  236.080002  233.800003  234.160004  4311000
# 2025-05-21  233.539993  237.300003  232.660004  234.860001  4631000
# 2025-05-22  230.270004  232.449997  229.419998  231.190002  6905100
#
# 이동평균 및 거래 신호 데이터:
#  Price            Close        5_MA       20_MA       50_MA      120_MA  \
# Ticker              GE
# Date
# 2025-05-09  214.960007  211.382004  197.287499  196.558825  189.438929
# 2025-05-12  218.949997  213.384003  199.151499  196.805912  189.782020
# 2025-05-13  221.580002  215.980002  200.930499  197.205814  190.159235
# 2025-05-14  223.240005  218.644003  202.809000  197.702596  190.545384
# 2025-05-15  229.380005  221.622003  205.155500  198.247718  190.982368
# 2025-05-16  231.779999  224.986002  207.655000  198.969600  191.435863
# 2025-05-19  235.289993  228.254001  210.502000  199.805599  191.912630
# 2025-05-20  235.259995  230.989999  212.806000  200.668399  192.368801
# 2025-05-21  233.539993  233.049997  214.799000  201.504799  192.818444
# 2025-05-22  230.270004  233.227997  216.442000  202.210199  193.204382
#
# Price           200_MA Signal Position Is_Bullish_Aligned Nice_Entry_Signal
# Ticker
# Date
# 2025-05-09  183.971829      1      0.0                  1                 1
# 2025-05-12  184.259100      1      0.0                  1                 0
# 2025-05-13  184.547729      1      0.0                  1                 0
# 2025-05-14  184.819085      1      0.0                  1                 0
# 2025-05-15  185.120843      1      0.0                  1                 0
# 2025-05-16  185.446492      1      0.0                  1                 0
# 2025-05-19  185.776158      1      0.0                  1                 0
# 2025-05-20  186.107913      1      0.0                  1                 0
# 2025-05-21  186.478183      1      0.0                  1                 0
# 2025-05-22  186.841656      1      0.0                  1                 0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = '260970.KQ'  # 에스앤디 (코스닥)
end_date = datetime.now()
start_date = end_date - timedelta(days=365)  # 최근 1년 데이터로 분석

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"⚠️ {ticker} 데이터 불러오기 실패!")
else:
    print(f"✅ {ticker} 최근 1년 데이터 (정배열 분석)\n")

    # 2. 이동평균 계산 (5일선 포함)
    windows = [5, 20, 50, 120, 200]
    ma_labels = ['5일', '20일', '50일', '120일', '200일']
    
    for window in windows:
        data[f'MA_{window}'] = data['Close'].rolling(window=window).mean()

    # 3. 정배열 여부 판단 (5>20>50>120>200)
    data['정배열'] = (
        (data['MA_5'] > data['MA_20']) & 
        (data['MA_20'] > data['MA_50']) & 
        (data['MA_50'] > data['MA_120']) & 
        (data['MA_120'] > data['MA_200'])
    )

    # 4. 거래 신호 (정배열 + 5일선 > 20일선 골든크로스 시 매수)
    data['Signal'] = 0
    data.loc[data['정배열'] & (data['MA_5'] > data['MA_20']), 'Signal'] = 1
    data['Position'] = data['Signal'].diff()

    # 5. 시각화 (정배열 강조)
    plt.figure(figsize=(16, 8))
    
    # 주가 및 이평선
    plt.plot(data['Close'], label='종가', color='#333333', lw=2, alpha=0.8)
    colors = ['#FF9AA2', '#FFB7B2', '#FFDAC1', '#E2F0CB', '#B5EAD7']
    for window, color in zip(windows, colors):
        plt.plot(data[f'MA_{window}'], label=f'{window}일선', color=color, lw=1.5)

    # 정배열 구간 색칠
    plt.fill_between(data.index, 0, data['Close'].max(), 
                    where=data['정배열'], 
                    color='green', alpha=0.1, label='정배열 구간')

    # 매수/매도 신호
    plt.scatter(data[data['Position'] == 1].index,
               data['MA_5'][data['Position'] == 1],
               marker='^', s=150, color='#2ECC71', label='매수 신호 (정배열 + 골든크로스)')
    plt.scatter(data[data['Position'] == -1].index,
               data['MA_5'][data['Position'] == -1],
               marker='v', s=150, color='#E74C3C', label='매도 신호')

    plt.title(f'🚀 {ticker} 정배열 분석 (5>20>50>120>200)', fontsize=16)
    plt.xlabel('날짜', fontsize=12)
    plt.ylabel('주가 (원)', fontsize=12)
    plt.legend(loc='upper left')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

    # 6. 최근 정배열 상태 출력
    recent_status = "정배열" if data['정배열'].iloc[-1] else "역배열 또는 비정배열"
    print(f"📈 최근 상태: {recent_status}")
    print(f"📊 5일선 위치: {data['MA_5'].iloc[-1]:.0f}원")
    print(f"📉 200일선 위치: {data['MA_200'].iloc[-1]:.0f}원\n")
# Out:
# ✅ 260970.KQ 최근 1년 데이터 (정배열 분석)
# C:\Users\glasr\AppData\Local\Temp\ipykernel_31532\527460217.py:66: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   plt.tight_layout()
# C:\Users\glasr\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📈 최근 상태: 역배열 또는 비정배열
# 📊 5일선 위치: 89800원
# 📉 200일선 위치: 50375원

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 1. 데이터 다운로드
ticker = 'PLTR'  # 미국 주식 티커 (예: Apple Inc.)
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)  # 최근 5년 데이터로 분석 (한국 코드와 동일하게 1년으로도 가능)

data = yf.download(ticker, start=start_date, end=end_date, progress=False)

if data.empty:
    print(f"⚠️ {ticker} 데이터 불러오기 실패! 티커를 확인하거나 날짜 범위를 조정해 주세요.")
else:
    print(f"✅ {ticker} 최근 5년 데이터 (정배열 분석)\n")

    # 2. 이동평균 계산 (5일선 포함)
    windows = [5, 20, 50, 120, 200]
    ma_labels = ['5-Day', '20-Day', '50-Day', '120-Day', '200-Day'] # 미국 주식에 맞는 라벨
    
    for window in windows:
        # min_periods=1을 추가하여 데이터 초반에도 MA가 계산되도록 함
        data[f'MA_{window}'] = data['Close'].rolling(window=window, min_periods=1).mean()

    # 3. 정배열 여부 판단 (5>20>50>120>200)
    # 모든 MA가 계산될 수 있는 최소 인덱스를 확보
    min_ma_idx = max(windows)

    if len(data) > min_ma_idx:
        data['Is_Bullish_Aligned'] = (
            (data['MA_5'] > data['MA_20']) &
            (data['MA_20'] > data['MA_50']) &
            (data['MA_50'] > data['MA_120']) &
            (data['MA_120'] > data['MA_200'])
        )
        # 초기 MA 계산 불가 구간은 False로 처리
        data['Is_Bullish_Aligned'] = data['Is_Bullish_Aligned'].fillna(False)
    else:
        print(f"Warning: 데이터({len(data)}일)가 부족하여 모든 이동평균선({max(windows)}일)을 계산하고 정배열을 판단하기 어렵습니다.")
        data['Is_Bullish_Aligned'] = False # 데이터 부족 시 정배열 아님

    # 4. 정배열 진입 신호 (역정배열에서 정배열로 전환되는 지점)
    if len(data) > min_ma_idx:
        data['Nice_Entry_Signal'] = np.where(
            (data['Is_Bullish_Aligned'].shift(1) == False) & (data['Is_Bullish_Aligned'] == True),
            1, 0
        )
        data['Nice_Entry_Signal'] = data['Nice_Entry_Signal'].fillna(0) # 초기 NaN 값 처리
    else:
        data['Nice_Entry_Signal'] = 0

    # 5. 거래 신호 (정배열 + 5일선 > 20일선 골든크로스 시 매수)
    data['Signal'] = 0
    # 정배열 조건을 만족하고, 5일선이 20일선 위에 있을 때 매수 포지션을 유지
    # 이 로직은 `Signal`이 `1`일 때 포지션을 보유한다는 의미
    min_trade_idx = max(5, 20)
    if len(data) > min_trade_idx:
        data.loc[data.index[min_trade_idx:], 'Signal'] = np.where(
            (data['Is_Bullish_Aligned'][min_trade_idx:]) & # 정배열이면서
            (data['MA_5'][min_trade_idx:] > data['MA_20'][min_trade_idx:]), # 5일선이 20일선 위에 있을 때
            1, 0
        )
    else:
        print("Warning: 거래 신호를 생성하기에 데이터가 부족합니다.")
        data['Signal'] = 0 # 데이터 부족 시 신호 없음

    data['Position'] = data['Signal'].diff()

    print("\n이동평균 및 거래 신호 데이터 (최근 10개):\n", data[['Close', 'MA_5', 'MA_20', 'MA_50', 'MA_120', 'MA_200', 'Is_Bullish_Aligned', 'Nice_Entry_Signal', 'Signal', 'Position']].tail(10))

    # 6. 시각화 (정배열 강조)
    plt.figure(figsize=(35, 18))
    
    # 주가 및 이평선
    plt.plot(data['Close'], label='Close Price', color='#0341fc', lw=2, alpha=1.0)
    # 이평선 색상 추가 (한국 코드와 동일한 색상 사용)
    colors = ['#df03fc', '#fc0320', '#fc7b03', '#07fc03', '#03fcf8']
    for window, color, label in zip(windows, colors, ma_labels): # label도 zip에 추가
        plt.plot(data[f'MA_{window}'], label=f'{label} MA', color=color, lw=1.5)

    # 정배열 구간 색칠 (Is_Bullish_Aligned가 True인 구간)
    plt.fill_between(data.index, data['Close'].min(), data['Close'].max(),
                     where=data['Is_Bullish_Aligned'],
                     color='green', alpha=0.1, label='Bullish Alignment Zone')

    # 매수/매도 신호
    # 매수 신호: Position이 1일 때 (포지션 진입)
    plt.scatter(data[data['Position'] == 1].index,
                data['Close'][data['Position'] == 1], # 종가 위치에 표시
                marker='^', s=500, color='#2ECC71', label='Buy Signal')
    # 매도 신호: Position이 -1일 때 (포지션 청산)
    plt.scatter(data[data['Position'] == -1].index,
                data['Close'][data['Position'] == -1], # 종가 위치에 표시
                marker='v', s=500, color='#E74C3C', label='Sell Signal')
    """
    # 정배열 진입 'nice' 신호 표시 (민트색 별)
    plt.scatter(data[data['Nice_Entry_Signal'] == 1].index,
                data['Close'][data['Nice_Entry_Signal'] == 1], # 종가 위치에 마커 표시
                marker='*', s=500, color='#000000', alpha=1.0, label='nice (Bullish Entry)')
    """
    plt.title(f'🚀 {ticker} Moving Average Analysis (5>20>50>120>200)', fontsize=16)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (USD)', fontsize=12) # 미국 주식은 USD
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10) # 범례를 그래프 밖에 배치
    plt.subplots_adjust(right=0.8) # 그래프 오른쪽 여백을 늘려 범례 공간 확보
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout(rect=[0, 0, 0.8, 1]) # bbox_to_anchor와 함께 사용 시 겹치지 않도록 조절
    plt.show()
    # 8. 최근 정배열 상태 출력
    # 200일 MA가 충분히 계산되지 않았을 수 있으므로 조건 추가
    if len(data) > 200 and 'Is_Bullish_Aligned' in data.columns:
        recent_is_aligned = data['Is_Bullish_Aligned'].iloc[-1]
        recent_status = "정배열" if recent_is_aligned else "역배열 또는 비정배열"
        print(f"📈 최근 상태: {recent_status}")
        print(f"📊 5일선 위치: ${data['MA_5'].iloc[-1]:,.2f}")
        print(f"📉 200일선 위치: ${data['MA_200'].iloc[-1]:,.2f}\n")
    else:
        print(f"📈 최근 200일선 데이터 부족으로 정배열 상태를 정확히 판단하기 어렵습니다. ({len(data)}일 데이터)")
# Out:
# ✅ PLTR 최근 5년 데이터 (정배열 분석)
#
#
# 이동평균 및 거래 신호 데이터 (최근 10개):
#  Price            Close        MA_5       MA_20     MA_50     MA_120    MA_200  \
# Ticker            PLTR
# Date
# 2025-05-09  117.300003  115.912001  107.072001   94.0136  86.254333  66.61950
# 2025-05-12  118.459999  114.850002  108.567500   94.6844  86.748333  67.07880
# 2025-05-13  128.100006  118.698003  110.341500   95.5780  87.267750  67.58615
# 2025-05-14  130.179993  122.638000  111.930500   96.4936  87.842083  68.10115
# 2025-05-15  128.119995  124.431999  113.701000   97.2534  88.384917  68.60635
# 2025-05-16  129.520004  126.875999  115.488000   98.2346  88.946583  69.12210
# 2025-05-19  126.330002  128.450000  117.264500   99.0630  89.488000  69.61930
# 2025-05-20  125.589996  127.947998  118.844500  100.0472  89.998333  70.11685
# 2025-05-21  120.580002  126.028000  119.832500  100.8978  90.464417  70.59605
# 2025-05-22  122.290001  124.862001  120.558000  101.6706  90.935667  71.08705
#
# Price      Is_Bullish_Aligned Nice_Entry_Signal Signal Position
# Ticker
# Date
# 2025-05-09               True                 0      1      0.0
# 2025-05-12               True                 0      1      0.0
# 2025-05-13               True                 0      1      0.0
# 2025-05-14               True                 0      1      0.0
# 2025-05-15               True                 0      1      0.0
# 2025-05-16               True                 0      1      0.0
# 2025-05-19               True                 0      1      0.0
# 2025-05-20               True                 0      1      0.0
# 2025-05-21               True                 0      1      0.0
# 2025-05-22               True                 0      1      0.0
# C:\Users\glasr\AppData\Local\Temp\ipykernel_31532\2080058861.py:109: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   plt.tight_layout(rect=[0, 0, 0.8, 1]) # bbox_to_anchor와 함께 사용 시 겹치지 않도록 조절
# C:\Users\glasr\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📈 최근 상태: 정배열
# 📊 5일선 위치: $124.86
# 📉 200일선 위치: $71.09

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 1. 시스템에 설치된 한글 폰트 찾기
font_path = fm.findSystemFonts(fontpaths=None, fontext='ttf')
kor_font = [f for f in font_path if 'malgun' in f.lower() or 'gothic' in f.lower()][0]  # 맑은 고딕 또는 굴림체 선택

# 2. 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 기준
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 3. 그래프 출력
plt.title('한글 제목 테스트')
plt.plot([1, 2, 3], label='한글 라벨')
plt.legend()
plt.show()
